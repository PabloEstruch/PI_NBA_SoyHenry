# %%
import pandas as pd
import numpy as np

# %%
import os

print(os.getcwd())  # Muestra la ruta actual
print(os.listdir())  # Muestra los archivos en la carpeta actual
# Out:
# c:\Users\Marcela Erazo\Desktop\Proyecto_Final
# ['team.csv', 'team_details.csv', 'team_history.csv', 'Untitled-1.ipynb', 'venv']

# %%
df = pd.read_csv('team.csv')

# %%
np.shape(df)
# Out:
# (30, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            30 non-null     int64
#  1   full_name     30 non-null     object
#  2   abbreviation  30 non-null     object
#  3   nickname      30 non-null     object
#  4   city          30 non-null     object
#  5   state         30 non-null     object
#  6   year_founded  30 non-null     float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.8+ KB

# %%
df
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
df = df.drop(columns=['year_founded'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            30 non-null     int64
#  1   full_name     30 non-null     object
#  2   abbreviation  30 non-null     object
#  3   nickname      30 non-null     object
#  4   city          30 non-null     object
#  5   state         30 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.5+ KB

# %%
#confirmamos nulos
data_nulos = df.isnull().sum()[df.isnull().sum()>0]
print(data_nulos)
# Out:
# Series([], dtype: int64)

# %%
df2 = pd.read_csv('team_details.csv')
df2
# Out:
#        team_id abbreviation       nickname  yearfounded           city  \
# 0   1610612737          ATL          Hawks       1949.0        Atlanta
# 1   1610612741          CHI          Bulls       1966.0        Chicago
# 2   1610612742          DAL      Mavericks       1980.0         Dallas
# 3   1610612743          DEN        Nuggets       1976.0         Denver
# 4   1610612744          GSW       Warriors       1946.0   Golden State
# 5   1610612745          HOU        Rockets       1967.0        Houston
# 6   1610612746          LAC       Clippers       1970.0    Los Angeles
# 7   1610612747          LAL         Lakers       1948.0    Los Angeles
# 8   1610612748          MIA           Heat       1988.0          Miami
# 9   1610612749          MIL          Bucks       1968.0      Milwaukee
# 10  1610612750          MIN   Timberwolves       1989.0      Minnesota
# 11  1610612751          BKN           Nets       1976.0       Brooklyn
# ...

# %%
np.shape(df2)
#faltan 5 equipos
# Out:
# (25, 14)

# %%
#buscamos los valores faltantes
diferencias = df[~df['abbreviation'].isin(df2['abbreviation'])]
print(diferencias['abbreviation'])
# Out:
# 1     BOS
# 2     CLE
# 3     NOP
# 15    NYK
# 16    ORL
# Name: abbreviation, dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   team_id             25 non-null     int64
#  1   abbreviation        25 non-null     object
#  2   nickname            25 non-null     object
#  3   yearfounded         25 non-null     float64
#  4   city                25 non-null     object
#  5   arena               25 non-null     object
#  6   arenacapacity       16 non-null     float64
#  7   owner               25 non-null     object
#  8   generalmanager      25 non-null     object
#  9   headcoach           24 non-null     object
#  10  dleagueaffiliation  25 non-null     object
#  11  facebook            25 non-null     object
#  12  instagram           25 non-null     object
#  13  twitter             25 non-null     object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 2.9+ KB

# %%
#preguntar por los owner
nuevos_registros = [
    {
        'team_id': '1610612738',
        'abbreviation': 'BOS',
        'nickname': 'Celtics',
        'yearfounded': '1946',
        'city': 'Boston',
        'arena': 'TD Garden',
        'arenacapacity': '18624',
        'owner': 'Wyc Grousbeck',
        'generalmanager': 'Brad Stevens',
        'headcoach': 'Joe Mazzulla',
        'dleagueaffiliation': 'Maine Celtics',
        'facebook': 'https://web.facebook.com/bostonceltics/',
        'instagram': 'https://www.instagram.com/celtics/',
        'twitter': 'https://x.com/celtics'
    },
    {
        'team_id': '1610612739',
        'abbreviation': 'CLE',
        'nickname': 'Cavaliers',
        'yearfounded': '1970',
        'city': 'cleveland',
        'arena': 'Rocket Arena',
        'arenacapacity': '19432',
        'owner': 'Dan Gilbert',
        'generalmanager': 'Mike Gansey',
        'headcoach': 'Kenny Atkinson',
        'dleagueaffiliation': 'The Cleveland Charge',
        'facebook': 'https://web.facebook.com/Cavs/',
        'instagram': 'https://www.instagram.com/cavs/',
        'twitter': 'https://x.com/cavs'
    },
    {
        'team_id': '1610612740',
        'abbreviation': 'NOP',
        'nickname': 'Pelicans',
        'yearfounded': '2002',
        'city': 'New Orleans',
        'arena': 'New Orleans Arena',
        'arenacapacity': '17791',
        'owner': 'Gayle Benson',
        'generalmanager': 'Bryson Graham',
        'headcoach': 'Willie Green',
        'dleagueaffiliation': 'Birmingham Squadron',
        'facebook': 'https://web.facebook.com/PelicansNBA/',
        'instagram': 'https://www.instagram.com/pelicansnba/',
        'twitter': 'https://x.com/PelicansNBA'
    },
    {
        'team_id': '1610612752',
        'abbreviation': 'NYK',
        'nickname': 'Knicks',
        'yearfounded': '1946',
        'city': 'New York',
        'arena': 'Madison Square Garden',
        'arenacapacity': '19500',
        'owner': 'James L. Dolan',
        'generalmanager': 'Gersson Rosas',
        'headcoach': 'Tom Thibodeau',
        'dleagueaffiliation': 'Westchester Knicks',
        'facebook': 'https://web.facebook.com/NYKnicks',
        'instagram': 'https://www.instagram.com/nyknicks',
        'twitter': 'https://x.com/nyknicks'
    },
    {
        'team_id': '1610612753',
        'abbreviation': 'ORL',
        'nickname': 'Magic',
        'yearfounded': '1989',
        'city': 'Orlando',
        'arena': 'Kia Center',
        'arenacapacity': '20000',
        'owner': 'RDV Sports, Inc.',
        'generalmanager': 'Anthony Parker',
        'headcoach': 'Jamahl Mosley',
        'dleagueaffiliation': 'Osceola Magic y Lakeland Magic',
        'facebook': 'https://web.facebook.com/OrlandoMagic/',
        'instagram': 'https://www.instagram.com/orlandomagic/',
        'twitter': 'https://x.com/OrlandoMagic'
    }
]
df2 = pd.concat([df2, pd.DataFrame(nuevos_registros)], ignore_index=True)

# %%
#confirmamos nulos
data_nulos = df2.isnull().sum()[df2.isnull().sum()>0]
print(data_nulos)
# Out:
# arenacapacity    9
# headcoach        1
# dtype: int64

# %%
df2_nulls = df2[df2["arenacapacity"].isnull()]["nickname"]
print(df2_nulls)
df2_nulls = df2[df2["headcoach"].isnull()]["nickname"]
print(df2_nulls)
# Out:
# 3      Nuggets
# 4     Warriors
# 11        Nets
# 13       76ers
# 14        Suns
# 18     Thunder
# 19     Raptors
# 20        Jazz
# 23     Pistons
# Name: nickname, dtype: object
# 19    Raptors
# Name: nickname, dtype: object

# %%
#tratamos los valores nulos uno a uno ya que hay pocos y son datos faciles de obtener
df2.loc[df2["nickname"] == "Nuggets", "arenacapacity"] = 21000 
df2.loc[df2["nickname"] == "Warriors", "arenacapacity"] = 18064
df2.loc[df2["nickname"] == "Nets", "arenacapacity"] = 19000
df2.loc[df2["nickname"] == "76ers", "arenacapacity"] = 21000
df2.loc[df2["nickname"] == "Suns", "arenacapacity"] = 18422
df2.loc[df2["nickname"] == "Thunder", "arenacapacity"] = 18203
df2.loc[df2["nickname"] == "Raptors", "arenacapacity"] = 19800
df2.loc[df2["nickname"] == "Jazz", "arenacapacity"] = 20000
df2.loc[df2["nickname"] == "Pistons", "arenacapacity"] = 20491

df2.loc[df2["nickname"] == "Raptors", "headcoach"] = 'Darko Rajaković'

# %%
#cambiamos el tipo de datos y orenamos
df2["team_id"] = df2["team_id"].astype(int)
df2["yearfounded"] = df2["yearfounded"].astype(int)
df2["arenacapacity"] = df2["arenacapacity"].astype(int)

df2= df2.sort_values(by='team_id').reset_index()

# %%
equipos_este = ["BOS", "BKN", "NYK", "PHI", "TOR", "ATL", "CHA", "MIA", "ORL", "WAS", "CHI", "CLE", "DET", "IND", "MIL"]

df2["Conferencia"] = df2["abbreviation"].apply(lambda x: "East" if x in equipos_este else "West")

# %%
df2 = pd.concat([df2, df[df.columns.difference(df2.columns)]], axis=1)

# %%
df2.drop(columns=["id", "dleagueaffiliation"], inplace=True)

# %%
# Obtener todas las columnas excepto "full_name"
columnas = list(df2.columns)
columnas.remove("full_name")

# Insertar "full_name" en la cuarta posición (índice 3)
columnas.insert(3, "full_name")

# Reordenar el DataFrame
df2 = df2[columnas]
# Out:
#     index     team_id abbreviation               full_name       nickname  \
# 0       0  1610612737          ATL           Atlanta Hawks          Hawks
# 1      25  1610612738          BOS          Boston Celtics        Celtics
# 2      26  1610612739          CLE     Cleveland Cavaliers      Cavaliers
# 3      27  1610612740          NOP    New Orleans Pelicans       Pelicans
# 4       1  1610612741          CHI           Chicago Bulls          Bulls
# 5       2  1610612742          DAL        Dallas Mavericks      Mavericks
# 6       3  1610612743          DEN          Denver Nuggets        Nuggets
# 7       4  1610612744          GSW   Golden State Warriors       Warriors
# 8       5  1610612745          HOU         Houston Rockets        Rockets
# 9       6  1610612746          LAC    Los Angeles Clippers       Clippers
# 10      7  1610612747          LAL      Los Angeles Lakers         Lakers
# 11      8  1610612748          MIA              Miami Heat           Heat
# ...

# %%
df2.to_csv("teams_final.csv", index=False)
