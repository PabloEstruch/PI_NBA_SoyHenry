# %%
import numpy as np
import pandas as pd

# %%
#lectura de los datos
df = pd.read_csv('Datos/play_by_play.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8e5a65ddaba2> in <cell line: 0>()
#       1 #lectura de los datos
# ----> 2 df = pd.read_csv('Datos/play_by_play.csv')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#lectura de los datos de game
game = pd.read_csv("Datos/game_filtrada.csv", usecols=["game_id"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13592899 entries, 0 to 13592898
# Data columns (total 34 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   game_id                    int64
#  1   eventnum                   int64
#  2   eventmsgtype               int64
#  3   eventmsgactiontype         int64
#  4   period                     int64
#  5   wctimestring               object
#  6   pctimestring               object
#  7   homedescription            object
#  8   neutraldescription         object
#  9   visitordescription         object
#  10  score                      object
#  11  scoremargin                object
#  12  person1type                float64
#  13  player1_id                 int64
#  14  player1_name               object
#  15  player1_team_id            float64
#  16  player1_team_city          object
#  17  player1_team_nickname      object
#  18  player1_team_abbreviation  object
# ...

# %%
df.head(10)
# Out:
#     game_id  eventnum  eventmsgtype  eventmsgactiontype  period wctimestring  \
# 0  29600012         0            12                   0       1     14:43 PM
# 1  29600012         2            10                   0       1     14:50 PM
# 2  29600012         3             2                   1       1     14:51 PM
# 3  29600012         4             4                   0       1     14:51 PM
# 4  29600012         5             2                   1       1     14:51 PM
# 5  29600012         6             4                   0       1     14:51 PM
# 6  29600012         7             6                   1       1     14:51 PM
# 7  29600012         8             5                   1       1     14:52 PM
# 8  29600012         9             2                   5       1     14:52 PM
# 9  29600012        10             4                   0       1     14:52 PM
#
#   pctimestring                              homedescription  \
# ...

# %%
df.tail(10)
# Out:
#            game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 13592889  32200001       632             4                   0       4
# 13592890  32200001       633             2                   2       4
# 13592891  32200001       634             4                   0       4
# 13592892  32200001       635             1                  50       4
# 13592893  32200001       637             5                  39       4
# 13592894  32200001       638             1                  79       4
# 13592895  32200001       639             2                   1       4
# 13592896  32200001       640             4                   0       4
# 13592897  32200001       641             1                  79       4
# 13592898  32200001       642            13                   0       4
#
#          wctimestring pctimestring  \
# 13592889     10:53 PM         0:00
# 13592890     10:53 PM         0:00
# 13592891     10:54 PM         0:00
# 13592892     10:54 PM         0:00
# ...

# %%
columnas_a_eliminar = ['wctimestring', 'eventnum', 'neutraldescription', 'person1type', 'person2type', 'person3type', 'player1_team_city', 'player1_team_nickname', 'player2_team_city',
                       'player2_team_nickname', 'player3_team_city', 'player3_team_nickname', 'video_available_flag', 'player3_id', 'player3_name', 'player3_team_id', 'player3_team_abbreviation',
                       'eventnum', 'eventmsgactiontype', 'pctimestring', 'scoremargin', 'player1_name', 'player1_team_id', 'player2_name','player2_team_id']

# Eliminar las columnas
df_filtrado = df.drop(columns=columnas_a_eliminar)

# %%
valores_unicos = len(pd.unique(df['game_id']))
valores_unicos
# Out:
# 29818

# %%
game_ids_filtrados = game['game_id'].unique().tolist()
game_ids_filtrados
# Out:
# [21800001,
#  21800002,
#  21800010,
#  21800013,
#  21800012,
#  21800007,
#  21800011,
#  21800009,
#  21800006,
#  21800005,
#  21800004,
#  21800003,
#  21800008,
#  21800016,
#  21800015,
#  21800014,
#  21800025,
#  21800018,
#  21800021,
#  21800017,
#  21800023,
#  21800019,
#  21800024,
#  21800020,
#  21800022,
#  21800030,
#  21800034,
#  21800026,
#  21800032,
#  21800035,
#  21800031,
#  21800027,
#  21800028,
#  21800033,
#  21800029,
#  21800038,
#  21800039,
#  21800036,
#  21800037,
#  21800042,
#  21800046,
#  21800048,
#  21800041,
#  21800044,
#  21800047,
#  21800040,
#  21800045,
#  21800043,
#  21800051,
#  21800050,
#  21800049,
#  21800060,
#  21800061,
#  21800055,
#  21800056,
#  21800059,
#  21800058,
#  21800057,
#  21800052,
#  21800054,
#  21800053,
#  21800062,
#  21800066,
#  21800065,
#  21800064,
#  21800063,
#  21800071,
#  21800072,
#  21800069,
#  21800068,
#  21800073,
#  21800067,
#  21800070,
#  21800080,
#  21800082,
#  21800079,
# ...

# %%
df_final = df_filtrado[df_filtrado['game_id'].isin(game_ids_filtrados)]
df_final
# Out:
#            game_id  eventmsgtype  period  \
# 10844963  21800001            12       1
# 10844964  21800001            10       1
# 10844965  21800001             2       1
# 10844966  21800001             4       1
# 10844967  21800001             2       1
# ...            ...           ...     ...
# 13592010  42200404             1       4
# 13592011  42200404             5       4
# 13592012  42200404             2       4
# 13592013  42200404             4       4
# 13592014  42200404            13       4
#
#                                           homedescription  \
# 10844963                                              NaN
# 10844964     Jump Ball Horford vs. Embiid: Tip to Simmons
# 10844965                                              NaN
# 10844966                                  CELTICS Rebound
# 10844967                     MISS Tatum 25' 3PT Jump Shot
# ...                                                   ...
# ...

# %%
valores_nulos = df_final.isnull().sum()[df_final.isnull().sum()>0]
print(valores_nulos)
# Out:
# homedescription              1279954
# visitordescription           1297152
# score                        1941916
# player1_team_abbreviation     221514
# player2_team_abbreviation    1787251
# dtype: int64

# %%
df_final[50:100]
# Out:
#            game_id  eventmsgtype  period  \
# 10845013  21800001             8       1
# 10845014  21800001             5       1
# 10845015  21800001             6       1
# 10845016  21800001             3       1
# 10845017  21800001             3       1
# 10845018  21800001             2       1
# 10845019  21800001             4       1
# 10845020  21800001             1       1
# 10845021  21800001             6       1
# 10845022  21800001             5       1
# 10845023  21800001             8       1
# 10845024  21800001             8       1
# 10845025  21800001             1       1
# 10845026  21800001             2       1
# 10845027  21800001             4       1
# 10845028  21800001             6       1
# 10845029  21800001             3       1
# 10845030  21800001             4       1
# 10845031  21800001             3       1
# 10845032  21800001             2       1
# 10845033  21800001             4       1
# 10845034  21800001             2       1
# ...

# %%
df_final.columns
# Out:
# Index(['game_id', 'eventmsgtype', 'period', 'homedescription',
#        'visitordescription', 'score', 'player1_id',
#        'player1_team_abbreviation', 'player2_id', 'player2_team_abbreviation'],
#       dtype='object')

# %%
eventos_analisis= [1, 2, 3, 4, 5, 6]
df_eventos = df_final[df_final['eventmsgtype'].isin(eventos_analisis)]
df_eventos
# Out:
#            game_id  eventmsgtype  period  \
# 10844965  21800001             2       1
# 10844966  21800001             4       1
# 10844967  21800001             2       1
# 10844968  21800001             4       1
# 10844969  21800001             5       1
# ...            ...           ...     ...
# 13592009  42200404             4       4
# 13592010  42200404             1       4
# 13592011  42200404             5       4
# 13592012  42200404             2       4
# 13592013  42200404             4       4
#
#                                           homedescription  \
# 10844965                                              NaN
# 10844966                                  CELTICS Rebound
# 10844967                     MISS Tatum 25' 3PT Jump Shot
# 10844968                                              NaN
# 10844969                            Hayward STEAL (1 STL)
# ...                                                   ...
# ...

# %%
df_eventos.to_csv('Datos/filtrado_play_by_play.csv',index=False)
